# %%
import pandas as pd

url = "https://datosabiertos.bogota.gov.co/dataset/9fc1f14b-540b-4adc-93b1-ecd22780d6d2/resource/f33d3941-9030-4899-9420-42ef8757607b/download/mortalidad-prematura-por-enfermedades-cronicas-general.csv"
df_mortalidad = pd.read_csv(url, encoding='latin-1', sep=None, engine='python')
print(df_mortalidad.shape)
print(df_mortalidad.columns.tolist())
df_mortalidad.head()
# Out:
# (164840, 13)
# ['ANO', 'MES', 'EAPS', 'SUBRED', 'SEXO', 'NACIONALIDAD DE LOS CASOS', 'REGIMEN_SEGURIDAD_SOCIAL', 'EDAD_FALLECIDO', 'EDAD_QUINQUENAL', 'CIE10_AGRUPADA', 'CIE10_BASICA', 'LOCALIDAD', 'CLASIFICACION_CRONICAS']
#     ANO  MES                                         EAPS         SUBRED  \
# 0  2023   10                             SALUD TOTAL S.A.            Sur
# 1  2023    7                             COMPENSAR E.P.S.  Sur Occidente
# 2  2023   12  FAMISANAR E.P.S. LTDA - CAFAM - COLSUBSIDIO          Norte
# 3  2023    8                                NUEVA EPS S.A  Sur Occidente
# 4  2023   12                                NUEVA EPS S.A          Norte
#
#         SEXO NACIONALIDAD DE LOS CASOS REGIMEN_SEGURIDAD_SOCIAL  \
# 0  Masculino                Colombiano             Contributivo
# 1  Masculino                Colombiano             Contributivo
# 2  Masculino                Colombiano             Contributivo
# ...

# %%
print(df_mortalidad.info())
print(df_mortalidad.isnull().sum())
print(df_mortalidad['CLASIFICACION_CRONICAS'].value_counts())
print(df_mortalidad['ANO'].value_counts().sort_index())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 164840 entries, 0 to 164839
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ANO                        164840 non-null  int64
#  1   MES                        164840 non-null  int64
#  2   EAPS                       164840 non-null  str
#  3   SUBRED                     164840 non-null  str
#  4   SEXO                       164840 non-null  str
#  5   NACIONALIDAD DE LOS CASOS  164840 non-null  str
#  6   REGIMEN_SEGURIDAD_SOCIAL   164840 non-null  str
#  7   EDAD_FALLECIDO             164840 non-null  int64
#  8   EDAD_QUINQUENAL            164840 non-null  str
#  9   CIE10_AGRUPADA             164840 non-null  str
#  10  CIE10_BASICA               164840 non-null  str
#  11  LOCALIDAD                  164840 non-null  str
#  12  CLASIFICACION_CRONICAS     164840 non-null  str
# dtypes: int64(3), str(10)
# memory usage: 36.9 MB
# None
# ...
